# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("corrdemo.csv")

# %%
df.head()
# Out:
#    A    B    C    D       E     F
# 0  0   91   92  308   28028  1552
# 1  1  327  335  360  117720  1786
# 2  2  207  210  227   46989  1116
# 3  3  133  156  362   48146  1785
# 4  4  102   74  322   32844  1543

# %%
df.corr()
# Out:
#           A         B         C         D         E         F
# A  1.000000  0.007077  0.008289  0.008578  0.009334  0.008630
# B  0.007077  1.000000  0.980161 -0.002679  0.932497 -0.004480
# C  0.008289  0.980161  1.000000 -0.003477  0.914397 -0.005204
# D  0.008578 -0.002679 -0.003477  1.000000  0.309911  0.987325
# E  0.009334  0.932497  0.914397  0.309911  1.000000  0.304317
# F  0.008630 -0.004480 -0.005204  0.987325  0.304317  1.000000

# %%
sb.heatmap(df.corr(),cmap="YlGnBu")

# %%
sb.heatmap(df.corr(),cmap="RdBu_r", annot=True)

# %%
sb.pairplot(df)

# %%
#################################################
# ask seaborn to plot the hist with 50 bins

# %%
sb.pairplot(df, diag_kws={'bins':50})

# %%
df.describe()
# Out:
#                  A             B             C             D              E  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    4999.50000    252.391400    252.778700    300.723200   75877.332800
# std     2886.89568    145.100664    147.926709     58.190379   46728.672695
# min        0.00000      1.000000    -44.000000    200.000000     206.000000
# 25%     2499.75000    126.000000    128.000000    250.000000   36176.750000
# 50%     4999.50000    253.000000    255.000000    302.000000   73378.000000
# 75%     7499.25000    379.000000    380.000000    351.000000  110170.750000
# max     9999.00000    500.000000    548.000000    400.000000  198500.000000
#
#                   F
# count  10000.000000
# mean    1462.784500
# std      294.231157
# min      884.000000
# 25%     1212.000000
# 50%     1467.000000
# 75%     1713.000000
# max     2035.000000
